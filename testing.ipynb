# %%
#  Given a string, remove all adjacent pairs of the same character. Repeat the process until no adjacent pairs remain.
#  Example:
#  Input: "abbaacc" → Output: "b"

# %%
def remove_adjacent_pairs(s):
   i=0
   changed = True
   result = []
   while i<len(s):
      if i+1 < len(s) and s[i] == s[i+1]:
         i+=2 
         changed = True
      else:
         result.append(s[i])
         i+=1

    result = ".join()

# %%
remove_adjacent_pairs("abbaacc")
# Out:
# 'a'

# %%
# Write a Python function that encodes a number using the following rules:


# For numbers divisible by 3, add "Fizz"


# For numbers divisible by 5, add "Buzz"


# For numbers divisible by both, return "FizzBuzz"
#  Example:
#  Input: 15 → Output: "FizzBuzz"
#  Input: 7 → Output: "7"

# %%
5%2
# Out:
# 1

# %%
def func(num):
    if num%3 ==0 and num%5 ==0:
        return "FizzBuzz"
    elif num%3 == 0:
        return "Fizz"
    elif num%5 ==0:
        return "Buzz"
    else:
        return num

# %%
func(7)
# Out:
# 7
